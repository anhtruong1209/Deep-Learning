# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 876us/sample - loss: 259.6121 - y1_output_loss: 123.0123 - y2_output_loss: 134.2797 - y1_output_root_mean_squared_error: 11.1425 - y2_output_root_mean_squared_error: 11.6386 - val_loss: 38.6251 - val_y1_output_loss: 14.1114 - val_y2_output_loss: 24.7826 - val_y1_output_root_mean_squared_error: 3.7818 - val_y2_output_root_mean_squared_error: 4.9318
# Epoch 2/500
# 614/614 [==============================] - 0s 130us/sample - loss: 33.0967 - y1_output_loss: 12.5501 - y2_output_loss: 20.3699 - y1_output_root_mean_squared_error: 3.5470 - y2_output_root_mean_squared_error: 4.5294 - val_loss: 35.5228 - val_y1_output_loss: 12.0996 - val_y2_output_loss: 23.0685 - val_y1_output_root_mean_squared_error: 3.5181 - val_y2_output_root_mean_squared_error: 4.8110
# Epoch 3/500
# 614/614 [==============================] - 0s 144us/sample - loss: 26.3750 - y1_output_loss: 10.0610 - y2_output_loss: 16.0857 - y1_output_root_mean_squared_error: 3.1856 - y2_output_root_mean_squared_error: 4.0282 - val_loss: 33.6298 - val_y1_output_loss: 14.2299 - val_y2_output_loss: 21.2297 - val_y1_output_root_mean_squared_error: 3.6867 - val_y2_output_root_mean_squared_error: 4.4764
# Epoch 4/500
# 614/614 [==============================] - 0s 123us/sample - loss: 27.3840 - y1_output_loss: 9.9594 - y2_output_loss: 17.2130 - y1_output_root_mean_squared_error: 3.1687 - y2_output_root_mean_squared_error: 4.1645 - val_loss: 19.8379 - val_y1_output_loss: 9.0581 - val_y2_output_loss: 10.8984 - val_y1_output_root_mean_squared_error: 3.0019 - val_y2_output_root_mean_squared_error: 3.2903
# Epoch 5/500
# 614/614 [==============================] - 0s 125us/sample - loss: 22.4724 - y1_output_loss: 8.6799 - y2_output_loss: 14.2909 - y1_output_root_mean_squared_error: 2.9356 - y2_output_root_mean_squared_error: 3.7222 - val_loss: 74.2286 - val_y1_output_loss: 19.4854 - val_y2_output_loss: 54.9584 - val_y1_output_root_mean_squared_error: 4.4194 - val_y2_output_root_mean_squared_error: 7.3958
# Epoch 6/500
# 614/614 [==============================] - 0s 127us/sample - loss: 21.7870 - y1_output_loss: 8.7836 - y2_output_loss: 13.2505 - y1_output_root_mean_squared_error: 2.9383 - y2_output_root_mean_squared_error: 3.6267 - val_loss: 60.1135 - val_y1_output_loss: 15.8050 - val_y2_output_loss: 43.9524 - val_y1_output_root_mean_squared_error: 4.0039 - val_y2_output_root_mean_squared_error: 6.6395
# Epoch 7/500
# 614/614 [==============================] - 0s 121us/sample - loss: 21.1881 - y1_output_loss: 8.3250 - y2_output_loss: 12.8753 - y1_output_root_mean_squared_error: 2.8727 - y2_output_root_mean_squared_error: 3.5966 - val_loss: 28.8151 - val_y1_output_loss: 10.7448 - val_y2_output_loss: 17.8773 - val_y1_output_root_mean_squared_error: 3.3066 - val_y2_output_root_mean_squared_error: 4.2287
# Epoch 8/500
# 614/614 [==============================] - 0s 126us/sample - loss: 21.4203 - y1_output_loss: 8.2303 - y2_output_loss: 13.0736 - y1_output_root_mean_squared_error: 2.8779 - y2_output_root_mean_squared_error: 3.6246 - val_loss: 18.7953 - val_y1_output_loss: 8.5860 - val_y2_output_loss: 10.5516 - val_y1_output_root_mean_squared_error: 2.9108 - val_y2_output_root_mean_squared_error: 3.2129
# Epoch 9/500
# 614/614 [==============================] - 0s 125us/sample - loss: 27.0122 - y1_output_loss: 8.9860 - y2_output_loss: 18.7548 - y1_output_root_mean_squared_error: 3.0047 - y2_output_root_mean_squared_error: 4.2407 - val_loss: 48.5220 - val_y1_output_loss: 14.9672 - val_y2_output_loss: 33.2576 - val_y1_output_root_mean_squared_error: 3.9017 - val_y2_output_root_mean_squared_error: 5.7705
# Epoch 10/500
# 614/614 [==============================] - 0s 122us/sample - loss: 20.2902 - y1_output_loss: 8.1064 - y2_output_loss: 12.3107 - y1_output_root_mean_squared_error: 2.8453 - y2_output_root_mean_squared_error: 3.4921 - val_loss: 26.4300 - val_y1_output_loss: 11.0495 - val_y2_output_loss: 16.5510 - val_y1_output_root_mean_squared_error: 3.2593 - val_y2_output_root_mean_squared_error: 3.9758
# Epoch 11/500
# 614/614 [==============================] - 0s 120us/sample - loss: 20.2872 - y1_output_loss: 7.6092 - y2_output_loss: 12.6489 - y1_output_root_mean_squared_error: 2.7521 - y2_output_root_mean_squared_error: 3.5656 - val_loss: 29.9372 - val_y1_output_loss: 10.0605 - val_y2_output_loss: 20.0166 - val_y1_output_root_mean_squared_error: 3.1651 - val_y2_output_root_mean_squared_error: 4.4631
# Epoch 12/500
# 614/614 [==============================] - 0s 121us/sample - loss: 23.5968 - y1_output_loss: 8.6318 - y2_output_loss: 15.1809 - y1_output_root_mean_squared_error: 2.9329 - y2_output_root_mean_squared_error: 3.8724 - val_loss: 19.7239 - val_y1_output_loss: 8.6112 - val_y2_output_loss: 11.2338 - val_y1_output_root_mean_squared_error: 2.9164 - val_y2_output_root_mean_squared_error: 3.3494
# Epoch 13/500
# 614/614 [==============================] - 0s 121us/sample - loss: 22.7475 - y1_output_loss: 8.2023 - y2_output_loss: 14.5475 - y1_output_root_mean_squared_error: 2.8498 - y2_output_root_mean_squared_error: 3.8244 - val_loss: 28.8659 - val_y1_output_loss: 13.2223 - val_y2_output_loss: 17.1322 - val_y1_output_root_mean_squared_error: 3.5542 - val_y2_output_root_mean_squared_error: 4.0291
# Epoch 14/500
# 614/614 [==============================] - 0s 122us/sample - loss: 19.2240 - y1_output_loss: 7.6621 - y2_output_loss: 11.5482 - y1_output_root_mean_squared_error: 2.7559 - y2_output_root_mean_squared_error: 3.4101 - val_loss: 29.8286 - val_y1_output_loss: 10.2316 - val_y2_output_loss: 19.8658 - val_y1_output_root_mean_squared_error: 3.2004 - val_y2_output_root_mean_squared_error: 4.4256
# Epoch 15/500
# 614/614 [==============================] - 0s 122us/sample - loss: 18.6194 - y1_output_loss: 6.8323 - y2_output_loss: 11.8725 - y1_output_root_mean_squared_error: 2.6047 - y2_output_root_mean_squared_error: 3.4402 - val_loss: 20.9987 - val_y1_output_loss: 8.5180 - val_y2_output_loss: 13.1789 - val_y1_output_root_mean_squared_error: 2.8912 - val_y2_output_root_mean_squared_error: 3.5552
# Epoch 16/500
# 614/614 [==============================] - 0s 121us/sample - loss: 18.5480 - y1_output_loss: 6.9072 - y2_output_loss: 11.5649 - y1_output_root_mean_squared_error: 2.6385 - y2_output_root_mean_squared_error: 3.4039 - val_loss: 29.8000 - val_y1_output_loss: 10.8967 - val_y2_output_loss: 20.3507 - val_y1_output_root_mean_squared_error: 3.2282 - val_y2_output_root_mean_squared_error: 4.4021
# Epoch 17/500
# 614/614 [==============================] - 0s 123us/sample - loss: 16.0903 - y1_output_loss: 6.2078 - y2_output_loss: 9.8702 - y1_output_root_mean_squared_error: 2.4960 - y2_output_root_mean_squared_error: 3.1401 - val_loss: 18.5119 - val_y1_output_loss: 8.1649 - val_y2_output_loss: 10.8190 - val_y1_output_root_mean_squared_error: 2.8462 - val_y2_output_root_mean_squared_error: 3.2266
# Epoch 18/500
# 614/614 [==============================] - 0s 130us/sample - loss: 15.2628 - y1_output_loss: 5.9392 - y2_output_loss: 9.2603 - y1_output_root_mean_squared_error: 2.4452 - y2_output_root_mean_squared_error: 3.0469 - val_loss: 32.1101 - val_y1_output_loss: 9.9886 - val_y2_output_loss: 23.6050 - val_y1_output_root_mean_squared_error: 3.0969 - val_y2_output_root_mean_squared_error: 4.7455
# Epoch 19/500
# 614/614 [==============================] - 0s 129us/sample - loss: 16.2764 - y1_output_loss: 5.8579 - y2_output_loss: 10.3250 - y1_output_root_mean_squared_error: 2.4288 - y2_output_root_mean_squared_error: 3.2214 - val_loss: 17.2636 - val_y1_output_loss: 7.1838 - val_y2_output_loss: 10.9245 - val_y1_output_root_mean_squared_error: 2.6396 - val_y2_output_root_mean_squared_error: 3.2087
# Epoch 20/500
# 614/614 [==============================] - 0s 125us/sample - loss: 17.6331 - y1_output_loss: 6.4575 - y2_output_loss: 11.0823 - y1_output_root_mean_squared_error: 2.5495 - y2_output_root_mean_squared_error: 3.3367 - val_loss: 16.8896 - val_y1_output_loss: 7.4561 - val_y2_output_loss: 10.2848 - val_y1_output_root_mean_squared_error: 2.6852 - val_y2_output_root_mean_squared_error: 3.1112
# Epoch 21/500
# 614/614 [==============================] - 0s 125us/sample - loss: 13.6341 - y1_output_loss: 5.1769 - y2_output_loss: 8.3543 - y1_output_root_mean_squared_error: 2.2835 - y2_output_root_mean_squared_error: 2.9017 - val_loss: 14.1733 - val_y1_output_loss: 6.6566 - val_y2_output_loss: 8.1054 - val_y1_output_root_mean_squared_error: 2.5443 - val_y2_output_root_mean_squared_error: 2.7749
# Epoch 22/500
# 614/614 [==============================] - 0s 127us/sample - loss: 13.7108 - y1_output_loss: 5.1537 - y2_output_loss: 8.5470 - y1_output_root_mean_squared_error: 2.2642 - y2_output_root_mean_squared_error: 2.9299 - val_loss: 17.3502 - val_y1_output_loss: 8.3864 - val_y2_output_loss: 9.7481 - val_y1_output_root_mean_squared_error: 2.8707 - val_y2_output_root_mean_squared_error: 3.0182
# Epoch 23/500
# 614/614 [==============================] - 0s 121us/sample - loss: 14.2770 - y1_output_loss: 5.4601 - y2_output_loss: 8.9786 - y1_output_root_mean_squared_error: 2.3351 - y2_output_root_mean_squared_error: 2.9706 - val_loss: 55.4930 - val_y1_output_loss: 13.9783 - val_y2_output_loss: 43.6463 - val_y1_output_root_mean_squared_error: 3.6594 - val_y2_output_root_mean_squared_error: 6.4886
# Epoch 24/500
# 614/614 [==============================] - 0s 122us/sample - loss: 14.3930 - y1_output_loss: 5.0870 - y2_output_loss: 9.3965 - y1_output_root_mean_squared_error: 2.2546 - y2_output_root_mean_squared_error: 3.0512 - val_loss: 37.7828 - val_y1_output_loss: 11.2224 - val_y2_output_loss: 26.6999 - val_y1_output_root_mean_squared_error: 3.3572 - val_y2_output_root_mean_squared_error: 5.1490
# Epoch 25/500
# 614/614 [==============================] - 0s 123us/sample - loss: 13.0098 - y1_output_loss: 4.9466 - y2_output_loss: 7.9540 - y1_output_root_mean_squared_error: 2.2322 - y2_output_root_mean_squared_error: 2.8332 - val_loss: 14.6254 - val_y1_output_loss: 5.9315 - val_y2_output_loss: 9.3614 - val_y1_output_root_mean_squared_error: 2.3967 - val_y2_output_root_mean_squared_error: 2.9801
# Epoch 26/500
# 614/614 [==============================] - 0s 124us/sample - loss: 12.0290 - y1_output_loss: 4.7297 - y2_output_loss: 7.2650 - y1_output_root_mean_squared_error: 2.1797 - y2_output_root_mean_squared_error: 2.6978 - val_loss: 24.4248 - val_y1_output_loss: 8.9675 - val_y2_output_loss: 16.9110 - val_y1_output_root_mean_squared_error: 2.9177 - val_y2_output_root_mean_squared_error: 3.9889
# Epoch 27/500
# 614/614 [==============================] - 0s 123us/sample - loss: 14.4119 - y1_output_loss: 4.9354 - y2_output_loss: 9.5498 - y1_output_root_mean_squared_error: 2.2172 - y2_output_root_mean_squared_error: 3.0815 - val_loss: 16.2420 - val_y1_output_loss: 7.7071 - val_y2_output_loss: 8.9529 - val_y1_output_root_mean_squared_error: 2.7474 - val_y2_output_root_mean_squared_error: 2.9486
# Epoch 28/500
# 614/614 [==============================] - 0s 121us/sample - loss: 11.9845 - y1_output_loss: 4.7041 - y2_output_loss: 7.2343 - y1_output_root_mean_squared_error: 2.1779 - y2_output_root_mean_squared_error: 2.6909 - val_loss: 15.4436 - val_y1_output_loss: 8.1553 - val_y2_output_loss: 8.2797 - val_y1_output_root_mean_squared_error: 2.7871 - val_y2_output_root_mean_squared_error: 2.7705
# Epoch 29/500
# 614/614 [==============================] - 0s 120us/sample - loss: 13.8521 - y1_output_loss: 4.6922 - y2_output_loss: 9.0571 - y1_output_root_mean_squared_error: 2.1743 - y2_output_root_mean_squared_error: 3.0207 - val_loss: 14.1964 - val_y1_output_loss: 6.4821 - val_y2_output_loss: 8.4999 - val_y1_output_root_mean_squared_error: 2.5043 - val_y2_output_root_mean_squared_error: 2.8151
# Epoch 30/500
# 614/614 [==============================] - 0s 118us/sample - loss: 14.2083 - y1_output_loss: 5.1723 - y2_output_loss: 8.9170 - y1_output_root_mean_squared_error: 2.2837 - y2_output_root_mean_squared_error: 2.9988 - val_loss: 12.9901 - val_y1_output_loss: 5.5273 - val_y2_output_loss: 7.9107 - val_y1_output_root_mean_squared_error: 2.3356 - val_y2_output_root_mean_squared_error: 2.7450
# Epoch 31/500
# 614/614 [==============================] - 0s 125us/sample - loss: 11.7268 - y1_output_loss: 4.4978 - y2_output_loss: 7.2247 - y1_output_root_mean_squared_error: 2.1183 - y2_output_root_mean_squared_error: 2.6906 - val_loss: 16.4067 - val_y1_output_loss: 6.9383 - val_y2_output_loss: 10.5575 - val_y1_output_root_mean_squared_error: 2.5679 - val_y2_output_root_mean_squared_error: 3.1325
# Epoch 32/500
# 614/614 [==============================] - 0s 126us/sample - loss: 11.2597 - y1_output_loss: 4.2629 - y2_output_loss: 7.1867 - y1_output_root_mean_squared_error: 2.0320 - y2_output_root_mean_squared_error: 2.6703 - val_loss: 39.8732 - val_y1_output_loss: 12.9286 - val_y2_output_loss: 27.6647 - val_y1_output_root_mean_squared_error: 3.5857 - val_y2_output_root_mean_squared_error: 5.1977
# Epoch 33/500
# 614/614 [==============================] - 0s 125us/sample - loss: 12.7377 - y1_output_loss: 4.4379 - y2_output_loss: 8.3014 - y1_output_root_mean_squared_error: 2.1040 - y2_output_root_mean_squared_error: 2.8828 - val_loss: 18.6912 - val_y1_output_loss: 5.7621 - val_y2_output_loss: 13.4592 - val_y1_output_root_mean_squared_error: 2.3836 - val_y2_output_root_mean_squared_error: 3.6069
# Epoch 34/500
# 614/614 [==============================] - 0s 125us/sample - loss: 11.6655 - y1_output_loss: 3.9930 - y2_output_loss: 7.6493 - y1_output_root_mean_squared_error: 1.9991 - y2_output_root_mean_squared_error: 2.7693 - val_loss: 17.9132 - val_y1_output_loss: 5.7199 - val_y2_output_loss: 12.4400 - val_y1_output_root_mean_squared_error: 2.3936 - val_y2_output_root_mean_squared_error: 3.4905
# Epoch 35/500
# 614/614 [==============================] - 0s 118us/sample - loss: 13.1811 - y1_output_loss: 4.3807 - y2_output_loss: 8.6829 - y1_output_root_mean_squared_error: 2.1025 - y2_output_root_mean_squared_error: 2.9598 - val_loss: 13.7738 - val_y1_output_loss: 6.0412 - val_y2_output_loss: 8.5123 - val_y1_output_root_mean_squared_error: 2.4112 - val_y2_output_root_mean_squared_error: 2.8214
# Epoch 36/500
# 614/614 [==============================] - 0s 125us/sample - loss: 9.7181 - y1_output_loss: 3.4164 - y2_output_loss: 6.2248 - y1_output_root_mean_squared_error: 1.8550 - y2_output_root_mean_squared_error: 2.5054 - val_loss: 10.9682 - val_y1_output_loss: 4.9229 - val_y2_output_loss: 6.6165 - val_y1_output_root_mean_squared_error: 2.1874 - val_y2_output_root_mean_squared_error: 2.4866
# Epoch 37/500
# 614/614 [==============================] - 0s 125us/sample - loss: 8.8488 - y1_output_loss: 3.3941 - y2_output_loss: 5.4036 - y1_output_root_mean_squared_error: 1.8454 - y2_output_root_mean_squared_error: 2.3331 - val_loss: 11.4515 - val_y1_output_loss: 4.4503 - val_y2_output_loss: 7.3658 - val_y1_output_root_mean_squared_error: 2.1036 - val_y2_output_root_mean_squared_error: 2.6508
# Epoch 38/500
# 614/614 [==============================] - 0s 125us/sample - loss: 9.2712 - y1_output_loss: 3.4136 - y2_output_loss: 6.1329 - y1_output_root_mean_squared_error: 1.8240 - y2_output_root_mean_squared_error: 2.4381 - val_loss: 38.7510 - val_y1_output_loss: 10.6317 - val_y2_output_loss: 28.3725 - val_y1_output_root_mean_squared_error: 3.2751 - val_y2_output_root_mean_squared_error: 5.2938
# Epoch 39/500
# 614/614 [==============================] - 0s 120us/sample - loss: 10.6500 - y1_output_loss: 3.6975 - y2_output_loss: 6.8667 - y1_output_root_mean_squared_error: 1.9313 - y2_output_root_mean_squared_error: 2.6306 - val_loss: 9.7592 - val_y1_output_loss: 4.1223 - val_y2_output_loss: 6.0069 - val_y1_output_root_mean_squared_error: 2.0180 - val_y2_output_root_mean_squared_error: 2.3847
# Epoch 40/500
# 614/614 [==============================] - 0s 125us/sample - loss: 9.8383 - y1_output_loss: 3.3915 - y2_output_loss: 6.4421 - y1_output_root_mean_squared_error: 1.8449 - y2_output_root_mean_squared_error: 2.5366 - val_loss: 11.1303 - val_y1_output_loss: 4.5549 - val_y2_output_loss: 7.3335 - val_y1_output_root_mean_squared_error: 2.0941 - val_y2_output_root_mean_squared_error: 2.5971
# Epoch 41/500
# 614/614 [==============================] - 0s 128us/sample - loss: 10.0729 - y1_output_loss: 3.3279 - y2_output_loss: 6.6741 - y1_output_root_mean_squared_error: 1.8282 - y2_output_root_mean_squared_error: 2.5943 - val_loss: 8.6497 - val_y1_output_loss: 3.6740 - val_y2_output_loss: 5.3764 - val_y1_output_root_mean_squared_error: 1.8946 - val_y2_output_root_mean_squared_error: 2.2495
# Epoch 42/500
# 614/614 [==============================] - 0s 125us/sample - loss: 9.3123 - y1_output_loss: 3.2068 - y2_output_loss: 6.1318 - y1_output_root_mean_squared_error: 1.7803 - y2_output_root_mean_squared_error: 2.4785 - val_loss: 8.8094 - val_y1_output_loss: 3.5069 - val_y2_output_loss: 5.6636 - val_y1_output_root_mean_squared_error: 1.8622 - val_y2_output_root_mean_squared_error: 2.3112
# Epoch 43/500
# 614/614 [==============================] - 0s 126us/sample - loss: 7.8792 - y1_output_loss: 2.8186 - y2_output_loss: 5.1093 - y1_output_root_mean_squared_error: 1.6811 - y2_output_root_mean_squared_error: 2.2479 - val_loss: 8.7876 - val_y1_output_loss: 3.5054 - val_y2_output_loss: 5.5589 - val_y1_output_root_mean_squared_error: 1.8713 - val_y2_output_root_mean_squared_error: 2.2991
# Epoch 44/500
# 614/614 [==============================] - 0s 127us/sample - loss: 8.2262 - y1_output_loss: 2.8382 - y2_output_loss: 5.4090 - y1_output_root_mean_squared_error: 1.6860 - y2_output_root_mean_squared_error: 2.3203 - val_loss: 8.2418 - val_y1_output_loss: 3.6180 - val_y2_output_loss: 5.1769 - val_y1_output_root_mean_squared_error: 1.8645 - val_y2_output_root_mean_squared_error: 2.1830
# Epoch 45/500
# 614/614 [==============================] - 0s 122us/sample - loss: 7.9489 - y1_output_loss: 2.5150 - y2_output_loss: 5.4549 - y1_output_root_mean_squared_error: 1.5927 - y2_output_root_mean_squared_error: 2.3264 - val_loss: 14.3129 - val_y1_output_loss: 4.7895 - val_y2_output_loss: 10.0112 - val_y1_output_root_mean_squared_error: 2.1548 - val_y2_output_root_mean_squared_error: 3.1096
# Epoch 46/500
# 614/614 [==============================] - 0s 120us/sample - loss: 8.6749 - y1_output_loss: 2.8533 - y2_output_loss: 5.8232 - y1_output_root_mean_squared_error: 1.6960 - y2_output_root_mean_squared_error: 2.4080 - val_loss: 11.6694 - val_y1_output_loss: 4.5389 - val_y2_output_loss: 7.5503 - val_y1_output_root_mean_squared_error: 2.0985 - val_y2_output_root_mean_squared_error: 2.6955
# Epoch 47/500
# 614/614 [==============================] - 0s 121us/sample - loss: 6.6616 - y1_output_loss: 2.2917 - y2_output_loss: 4.4107 - y1_output_root_mean_squared_error: 1.5118 - y2_output_root_mean_squared_error: 2.0919 - val_loss: 13.9496 - val_y1_output_loss: 2.8915 - val_y2_output_loss: 11.2281 - val_y1_output_root_mean_squared_error: 1.7055 - val_y2_output_root_mean_squared_error: 3.3228
# Epoch 48/500
# 614/614 [==============================] - 0s 120us/sample - loss: 7.5161 - y1_output_loss: 2.4020 - y2_output_loss: 5.1240 - y1_output_root_mean_squared_error: 1.5480 - y2_output_root_mean_squared_error: 2.2627 - val_loss: 11.0791 - val_y1_output_loss: 2.9266 - val_y2_output_loss: 8.5413 - val_y1_output_root_mean_squared_error: 1.7056 - val_y2_output_root_mean_squared_error: 2.8583
# Epoch 49/500
# 614/614 [==============================] - 0s 121us/sample - loss: 7.4803 - y1_output_loss: 2.3414 - y2_output_loss: 5.0710 - y1_output_root_mean_squared_error: 1.5370 - y2_output_root_mean_squared_error: 2.2623 - val_loss: 6.7218 - val_y1_output_loss: 2.6668 - val_y2_output_loss: 4.4407 - val_y1_output_root_mean_squared_error: 1.6092 - val_y2_output_root_mean_squared_error: 2.0328
# Epoch 50/500
# 614/614 [==============================] - 0s 120us/sample - loss: 8.0487 - y1_output_loss: 2.4743 - y2_output_loss: 5.5415 - y1_output_root_mean_squared_error: 1.5739 - y2_output_root_mean_squared_error: 2.3604 - val_loss: 7.8080 - val_y1_output_loss: 2.8332 - val_y2_output_loss: 5.2381 - val_y1_output_root_mean_squared_error: 1.6827 - val_y2_output_root_mean_squared_error: 2.2308
# Epoch 51/500
# 614/614 [==============================] - 0s 121us/sample - loss: 8.5904 - y1_output_loss: 2.3574 - y2_output_loss: 6.1987 - y1_output_root_mean_squared_error: 1.5375 - y2_output_root_mean_squared_error: 2.4953 - val_loss: 6.3054 - val_y1_output_loss: 2.5129 - val_y2_output_loss: 4.0016 - val_y1_output_root_mean_squared_error: 1.5798 - val_y2_output_root_mean_squared_error: 1.9519
# Epoch 52/500
# 614/614 [==============================] - 0s 122us/sample - loss: 6.8208 - y1_output_loss: 2.0746 - y2_output_loss: 4.7764 - y1_output_root_mean_squared_error: 1.4444 - y2_output_root_mean_squared_error: 2.1759 - val_loss: 12.1375 - val_y1_output_loss: 4.6641 - val_y2_output_loss: 7.8438 - val_y1_output_root_mean_squared_error: 2.1280 - val_y2_output_root_mean_squared_error: 2.7585
# Epoch 53/500
# 614/614 [==============================] - 0s 122us/sample - loss: 6.8888 - y1_output_loss: 1.9700 - y2_output_loss: 4.8695 - y1_output_root_mean_squared_error: 1.4051 - y2_output_root_mean_squared_error: 2.2169 - val_loss: 6.7817 - val_y1_output_loss: 2.3881 - val_y2_output_loss: 4.6302 - val_y1_output_root_mean_squared_error: 1.5406 - val_y2_output_root_mean_squared_error: 2.0995
# Epoch 54/500
# 614/614 [==============================] - 0s 122us/sample - loss: 7.1208 - y1_output_loss: 1.9830 - y2_output_loss: 5.1390 - y1_output_root_mean_squared_error: 1.4136 - y2_output_root_mean_squared_error: 2.2633 - val_loss: 13.9072 - val_y1_output_loss: 5.8454 - val_y2_output_loss: 8.1791 - val_y1_output_root_mean_squared_error: 2.4224 - val_y2_output_root_mean_squared_error: 2.8353
# Epoch 55/500
# 614/614 [==============================] - 0s 125us/sample - loss: 7.5217 - y1_output_loss: 2.3913 - y2_output_loss: 5.0592 - y1_output_root_mean_squared_error: 1.5537 - y2_output_root_mean_squared_error: 2.2600 - val_loss: 6.4157 - val_y1_output_loss: 2.3419 - val_y2_output_loss: 4.1595 - val_y1_output_root_mean_squared_error: 1.5412 - val_y2_output_root_mean_squared_error: 2.0101
# Epoch 56/500
# 614/614 [==============================] - 0s 123us/sample - loss: 5.4982 - y1_output_loss: 1.4925 - y2_output_loss: 3.9800 - y1_output_root_mean_squared_error: 1.2264 - y2_output_root_mean_squared_error: 1.9985 - val_loss: 6.0530 - val_y1_output_loss: 2.3252 - val_y2_output_loss: 3.9128 - val_y1_output_root_mean_squared_error: 1.5163 - val_y2_output_root_mean_squared_error: 1.9375
# Epoch 57/500
# 614/614 [==============================] - 0s 121us/sample - loss: 6.5500 - y1_output_loss: 1.8720 - y2_output_loss: 4.7035 - y1_output_root_mean_squared_error: 1.3700 - y2_output_root_mean_squared_error: 2.1618 - val_loss: 20.0104 - val_y1_output_loss: 5.6105 - val_y2_output_loss: 14.9299 - val_y1_output_root_mean_squared_error: 2.3337 - val_y2_output_root_mean_squared_error: 3.8163
# Epoch 58/500
# 614/614 [==============================] - 0s 123us/sample - loss: 6.1184 - y1_output_loss: 1.8881 - y2_output_loss: 4.1965 - y1_output_root_mean_squared_error: 1.3784 - y2_output_root_mean_squared_error: 2.0539 - val_loss: 7.9942 - val_y1_output_loss: 2.2310 - val_y2_output_loss: 5.8759 - val_y1_output_root_mean_squared_error: 1.5068 - val_y2_output_root_mean_squared_error: 2.3924
# Epoch 59/500
# 614/614 [==============================] - 0s 125us/sample - loss: 7.6247 - y1_output_loss: 2.1206 - y2_output_loss: 5.4689 - y1_output_root_mean_squared_error: 1.4603 - y2_output_root_mean_squared_error: 2.3436 - val_loss: 8.3949 - val_y1_output_loss: 2.2979 - val_y2_output_loss: 6.1749 - val_y1_output_root_mean_squared_error: 1.5331 - val_y2_output_root_mean_squared_error: 2.4586
# Epoch 60/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.8234 - y1_output_loss: 1.7418 - y2_output_loss: 5.1829 - y1_output_root_mean_squared_error: 1.3120 - y2_output_root_mean_squared_error: 2.2588 - val_loss: 34.1864 - val_y1_output_loss: 12.2354 - val_y2_output_loss: 21.4633 - val_y1_output_root_mean_squared_error: 3.5359 - val_y2_output_root_mean_squared_error: 4.6566
# Epoch 61/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.4039 - y1_output_loss: 2.2123 - y2_output_loss: 5.1491 - y1_output_root_mean_squared_error: 1.4867 - y2_output_root_mean_squared_error: 2.2790 - val_loss: 7.9409 - val_y1_output_loss: 1.9540 - val_y2_output_loss: 6.1147 - val_y1_output_root_mean_squared_error: 1.4133 - val_y2_output_root_mean_squared_error: 2.4379
# Epoch 62/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.6988 - y1_output_loss: 1.5183 - y2_output_loss: 4.1866 - y1_output_root_mean_squared_error: 1.2338 - y2_output_root_mean_squared_error: 2.0437 - val_loss: 5.8879 - val_y1_output_loss: 2.0407 - val_y2_output_loss: 4.0292 - val_y1_output_root_mean_squared_error: 1.4378 - val_y2_output_root_mean_squared_error: 1.9547
# Epoch 63/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.9715 - y1_output_loss: 1.3834 - y2_output_loss: 3.6468 - y1_output_root_mean_squared_error: 1.1743 - y2_output_root_mean_squared_error: 1.8954 - val_loss: 10.0235 - val_y1_output_loss: 3.1536 - val_y2_output_loss: 7.0281 - val_y1_output_root_mean_squared_error: 1.7665 - val_y2_output_root_mean_squared_error: 2.6273
# Epoch 64/500
# 614/614 [==============================] - 0s 125us/sample - loss: 6.7914 - y1_output_loss: 1.9258 - y2_output_loss: 4.8933 - y1_output_root_mean_squared_error: 1.3867 - y2_output_root_mean_squared_error: 2.2064 - val_loss: 23.7053 - val_y1_output_loss: 5.6309 - val_y2_output_loss: 18.6676 - val_y1_output_root_mean_squared_error: 2.3346 - val_y2_output_root_mean_squared_error: 4.2726
# Epoch 65/500
# 614/614 [==============================] - 0s 120us/sample - loss: 5.9775 - y1_output_loss: 1.7138 - y2_output_loss: 4.2628 - y1_output_root_mean_squared_error: 1.3051 - y2_output_root_mean_squared_error: 2.0674 - val_loss: 7.4725 - val_y1_output_loss: 2.1271 - val_y2_output_loss: 5.5949 - val_y1_output_root_mean_squared_error: 1.4447 - val_y2_output_root_mean_squared_error: 2.3206
# Epoch 66/500
# 614/614 [==============================] - 0s 120us/sample - loss: 6.5466 - y1_output_loss: 1.6197 - y2_output_loss: 4.8849 - y1_output_root_mean_squared_error: 1.2782 - y2_output_root_mean_squared_error: 2.2165 - val_loss: 5.6788 - val_y1_output_loss: 1.7683 - val_y2_output_loss: 3.9537 - val_y1_output_root_mean_squared_error: 1.3426 - val_y2_output_root_mean_squared_error: 1.9688
# Epoch 67/500
# 614/614 [==============================] - 0s 121us/sample - loss: 5.7670 - y1_output_loss: 1.4825 - y2_output_loss: 4.2612 - y1_output_root_mean_squared_error: 1.2215 - y2_output_root_mean_squared_error: 2.0676 - val_loss: 5.5186 - val_y1_output_loss: 1.6388 - val_y2_output_loss: 4.1394 - val_y1_output_root_mean_squared_error: 1.2718 - val_y2_output_root_mean_squared_error: 1.9752
# Epoch 68/500
# 614/614 [==============================] - 0s 118us/sample - loss: 6.1674 - y1_output_loss: 1.7637 - y2_output_loss: 4.3838 - y1_output_root_mean_squared_error: 1.3305 - y2_output_root_mean_squared_error: 2.0969 - val_loss: 5.9703 - val_y1_output_loss: 2.0438 - val_y2_output_loss: 4.1255 - val_y1_output_root_mean_squared_error: 1.4203 - val_y2_output_root_mean_squared_error: 1.9882
# Epoch 69/500
# 614/614 [==============================] - 0s 117us/sample - loss: 7.1496 - y1_output_loss: 1.8679 - y2_output_loss: 5.2863 - y1_output_root_mean_squared_error: 1.3648 - y2_output_root_mean_squared_error: 2.2993 - val_loss: 6.3690 - val_y1_output_loss: 2.5600 - val_y2_output_loss: 3.9562 - val_y1_output_root_mean_squared_error: 1.5837 - val_y2_output_root_mean_squared_error: 1.9649
# Epoch 70/500
# 614/614 [==============================] - 0s 117us/sample - loss: 4.9567 - y1_output_loss: 1.3705 - y2_output_loss: 3.5394 - y1_output_root_mean_squared_error: 1.1760 - y2_output_root_mean_squared_error: 1.8904 - val_loss: 4.0494 - val_y1_output_loss: 1.4066 - val_y2_output_loss: 2.7611 - val_y1_output_root_mean_squared_error: 1.1966 - val_y2_output_root_mean_squared_error: 1.6179
# Epoch 71/500
# 614/614 [==============================] - 0s 118us/sample - loss: 5.4714 - y1_output_loss: 1.4257 - y2_output_loss: 4.0557 - y1_output_root_mean_squared_error: 1.1965 - y2_output_root_mean_squared_error: 2.0100 - val_loss: 7.4821 - val_y1_output_loss: 1.9188 - val_y2_output_loss: 5.6770 - val_y1_output_root_mean_squared_error: 1.3781 - val_y2_output_root_mean_squared_error: 2.3628
# Epoch 72/500
# 614/614 [==============================] - 0s 118us/sample - loss: 5.2422 - y1_output_loss: 1.3330 - y2_output_loss: 3.9050 - y1_output_root_mean_squared_error: 1.1557 - y2_output_root_mean_squared_error: 1.9765 - val_loss: 6.4727 - val_y1_output_loss: 2.0177 - val_y2_output_loss: 4.4637 - val_y1_output_root_mean_squared_error: 1.4330 - val_y2_output_root_mean_squared_error: 2.1022
# Epoch 73/500
# 614/614 [==============================] - 0s 118us/sample - loss: 4.5256 - y1_output_loss: 1.2334 - y2_output_loss: 3.2721 - y1_output_root_mean_squared_error: 1.1129 - y2_output_root_mean_squared_error: 1.8130 - val_loss: 4.8077 - val_y1_output_loss: 1.6082 - val_y2_output_loss: 3.2935 - val_y1_output_root_mean_squared_error: 1.2738 - val_y2_output_root_mean_squared_error: 1.7847
# Epoch 74/500
# 614/614 [==============================] - 0s 119us/sample - loss: 3.6325 - y1_output_loss: 1.0820 - y2_output_loss: 2.5659 - y1_output_root_mean_squared_error: 1.0452 - y2_output_root_mean_squared_error: 1.5937 - val_loss: 15.4139 - val_y1_output_loss: 1.9492 - val_y2_output_loss: 13.7726 - val_y1_output_root_mean_squared_error: 1.3805 - val_y2_output_root_mean_squared_error: 3.6753
# Epoch 75/500
# 614/614 [==============================] - 0s 118us/sample - loss: 3.7460 - y1_output_loss: 0.9613 - y2_output_loss: 2.7999 - y1_output_root_mean_squared_error: 0.9833 - y2_output_root_mean_squared_error: 1.6671 - val_loss: 10.8579 - val_y1_output_loss: 1.8395 - val_y2_output_loss: 9.2886 - val_y1_output_root_mean_squared_error: 1.3449 - val_y2_output_root_mean_squared_error: 3.0082
# Epoch 76/500
# 614/614 [==============================] - 0s 123us/sample - loss: 5.4168 - y1_output_loss: 1.2711 - y2_output_loss: 4.1921 - y1_output_root_mean_squared_error: 1.1326 - y2_output_root_mean_squared_error: 2.0332 - val_loss: 6.1934 - val_y1_output_loss: 1.4682 - val_y2_output_loss: 4.7990 - val_y1_output_root_mean_squared_error: 1.2302 - val_y2_output_root_mean_squared_error: 2.1633
# Epoch 77/500
# 614/614 [==============================] - 0s 122us/sample - loss: 4.5316 - y1_output_loss: 1.0701 - y2_output_loss: 3.4309 - y1_output_root_mean_squared_error: 1.0376 - y2_output_root_mean_squared_error: 1.8588 - val_loss: 3.9477 - val_y1_output_loss: 1.2509 - val_y2_output_loss: 2.8345 - val_y1_output_root_mean_squared_error: 1.1298 - val_y2_output_root_mean_squared_error: 1.6344
# Epoch 78/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.8587 - y1_output_loss: 1.2247 - y2_output_loss: 3.6249 - y1_output_root_mean_squared_error: 1.1101 - y2_output_root_mean_squared_error: 1.9043 - val_loss: 5.9864 - val_y1_output_loss: 1.0422 - val_y2_output_loss: 5.0402 - val_y1_output_root_mean_squared_error: 1.0317 - val_y2_output_root_mean_squared_error: 2.2186
# Epoch 79/500
# 614/614 [==============================] - 0s 119us/sample - loss: 5.6402 - y1_output_loss: 1.4771 - y2_output_loss: 4.1134 - y1_output_root_mean_squared_error: 1.2205 - y2_output_root_mean_squared_error: 2.0373 - val_loss: 3.4468 - val_y1_output_loss: 1.0133 - val_y2_output_loss: 2.5826 - val_y1_output_root_mean_squared_error: 1.0133 - val_y2_output_root_mean_squared_error: 1.5557
# Epoch 80/500
# 614/614 [==============================] - 0s 119us/sample - loss: 4.4076 - y1_output_loss: 1.1438 - y2_output_loss: 3.3623 - y1_output_root_mean_squared_error: 1.0545 - y2_output_root_mean_squared_error: 1.8154 - val_loss: 9.4416 - val_y1_output_loss: 3.0552 - val_y2_output_loss: 6.5590 - val_y1_output_root_mean_squared_error: 1.7277 - val_y2_output_root_mean_squared_error: 2.5410
# Epoch 81/500
# 614/614 [==============================] - 0s 119us/sample - loss: 4.2205 - y1_output_loss: 1.0583 - y2_output_loss: 3.1730 - y1_output_root_mean_squared_error: 1.0228 - y2_output_root_mean_squared_error: 1.7816 - val_loss: 4.0583 - val_y1_output_loss: 1.2809 - val_y2_output_loss: 2.8881 - val_y1_output_root_mean_squared_error: 1.1430 - val_y2_output_root_mean_squared_error: 1.6588
# Epoch 82/500
# 614/614 [==============================] - 0s 119us/sample - loss: 3.4926 - y1_output_loss: 0.8612 - y2_output_loss: 2.6806 - y1_output_root_mean_squared_error: 0.9250 - y2_output_root_mean_squared_error: 1.6239 - val_loss: 15.3500 - val_y1_output_loss: 4.2271 - val_y2_output_loss: 11.2040 - val_y1_output_root_mean_squared_error: 2.0749 - val_y2_output_root_mean_squared_error: 3.3234
# Epoch 83/500
# 614/614 [==============================] - 0s 119us/sample - loss: 5.2089 - y1_output_loss: 1.3030 - y2_output_loss: 3.8802 - y1_output_root_mean_squared_error: 1.1446 - y2_output_root_mean_squared_error: 1.9746 - val_loss: 8.1424 - val_y1_output_loss: 2.4929 - val_y2_output_loss: 5.5238 - val_y1_output_root_mean_squared_error: 1.5997 - val_y2_output_root_mean_squared_error: 2.3629
# Epoch 84/500
# 614/614 [==============================] - 0s 123us/sample - loss: 4.7256 - y1_output_loss: 1.2033 - y2_output_loss: 3.5503 - y1_output_root_mean_squared_error: 1.0950 - y2_output_root_mean_squared_error: 1.8779 - val_loss: 8.8419 - val_y1_output_loss: 1.1757 - val_y2_output_loss: 7.7410 - val_y1_output_root_mean_squared_error: 1.1032 - val_y2_output_root_mean_squared_error: 2.7613
# Epoch 85/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.2328 - y1_output_loss: 0.8671 - y2_output_loss: 2.3961 - y1_output_root_mean_squared_error: 0.9273 - y2_output_root_mean_squared_error: 1.5404 - val_loss: 8.1835 - val_y1_output_loss: 1.9237 - val_y2_output_loss: 6.1594 - val_y1_output_root_mean_squared_error: 1.4060 - val_y2_output_root_mean_squared_error: 2.4913
# Epoch 86/500
# 614/614 [==============================] - 0s 121us/sample - loss: 3.6539 - y1_output_loss: 0.9297 - y2_output_loss: 2.7047 - y1_output_root_mean_squared_error: 0.9651 - y2_output_root_mean_squared_error: 1.6500 - val_loss: 3.6135 - val_y1_output_loss: 1.0174 - val_y2_output_loss: 2.6927 - val_y1_output_root_mean_squared_error: 1.0103 - val_y2_output_root_mean_squared_error: 1.6102
# Epoch 87/500
# 614/614 [==============================] - 0s 122us/sample - loss: 5.8665 - y1_output_loss: 1.4017 - y2_output_loss: 4.4727 - y1_output_root_mean_squared_error: 1.1850 - y2_output_root_mean_squared_error: 2.1124 - val_loss: 6.1573 - val_y1_output_loss: 1.5435 - val_y2_output_loss: 4.8191 - val_y1_output_root_mean_squared_error: 1.2440 - val_y2_output_root_mean_squared_error: 2.1471
# Epoch 88/500
# 614/614 [==============================] - 0s 122us/sample - loss: 3.6157 - y1_output_loss: 0.9466 - y2_output_loss: 2.6707 - y1_output_root_mean_squared_error: 0.9695 - y2_output_root_mean_squared_error: 1.6358 - val_loss: 4.8671 - val_y1_output_loss: 1.2153 - val_y2_output_loss: 3.8273 - val_y1_output_root_mean_squared_error: 1.0947 - val_y2_output_root_mean_squared_error: 1.9154
# Epoch 89/500
# 614/614 [==============================] - 0s 121us/sample - loss: 2.9407 - y1_output_loss: 0.7881 - y2_output_loss: 2.1658 - y1_output_root_mean_squared_error: 0.8719 - y2_output_root_mean_squared_error: 1.4767 - val_loss: 3.7774 - val_y1_output_loss: 1.2082 - val_y2_output_loss: 2.6620 - val_y1_output_root_mean_squared_error: 1.1003 - val_y2_output_root_mean_squared_error: 1.6021
# Epoch 90/500
# 614/614 [==============================] - 0s 124us/sample - loss: 4.4202 - y1_output_loss: 1.1715 - y2_output_loss: 3.2546 - y1_output_root_mean_squared_error: 1.0842 - y2_output_root_mean_squared_error: 1.8013 - val_loss: 4.7649 - val_y1_output_loss: 0.8408 - val_y2_output_loss: 4.0160 - val_y1_output_root_mean_squared_error: 0.9216 - val_y2_output_root_mean_squared_error: 1.9788
# Epoch 91/500
# 614/614 [==============================] - 0s 120us/sample - loss: 2.7488 - y1_output_loss: 0.6602 - y2_output_loss: 2.1199 - y1_output_root_mean_squared_error: 0.8127 - y2_output_root_mean_squared_error: 1.4451 - val_loss: 3.4999 - val_y1_output_loss: 0.8762 - val_y2_output_loss: 2.6916 - val_y1_output_root_mean_squared_error: 0.9462 - val_y2_output_root_mean_squared_error: 1.6139
# Epoch 92/500
# 614/614 [==============================] - 0s 122us/sample - loss: 3.0477 - y1_output_loss: 0.7227 - y2_output_loss: 2.3507 - y1_output_root_mean_squared_error: 0.8531 - y2_output_root_mean_squared_error: 1.5232 - val_loss: 9.0316 - val_y1_output_loss: 0.9241 - val_y2_output_loss: 8.2651 - val_y1_output_root_mean_squared_error: 0.9741 - val_y2_output_root_mean_squared_error: 2.8430
# Epoch 93/500
# 614/614 [==============================] - 0s 121us/sample - loss: 3.7576 - y1_output_loss: 0.7901 - y2_output_loss: 2.9484 - y1_output_root_mean_squared_error: 0.8881 - y2_output_root_mean_squared_error: 1.7231 - val_loss: 4.3762 - val_y1_output_loss: 1.5909 - val_y2_output_loss: 2.7982 - val_y1_output_root_mean_squared_error: 1.2751 - val_y2_output_root_mean_squared_error: 1.6584
# Epoch 94/500
# 614/614 [==============================] - 0s 121us/sample - loss: 4.9688 - y1_output_loss: 1.2938 - y2_output_loss: 3.7256 - y1_output_root_mean_squared_error: 1.1279 - y2_output_root_mean_squared_error: 1.9227 - val_loss: 11.7389 - val_y1_output_loss: 4.5062 - val_y2_output_loss: 7.0751 - val_y1_output_root_mean_squared_error: 2.1536 - val_y2_output_root_mean_squared_error: 2.6648
# Epoch 95/500
# 614/614 [==============================] - 0s 121us/sample - loss: 4.1066 - y1_output_loss: 1.1093 - y2_output_loss: 2.9783 - y1_output_root_mean_squared_error: 1.0578 - y2_output_root_mean_squared_error: 1.7285 - val_loss: 4.3395 - val_y1_output_loss: 1.0201 - val_y2_output_loss: 3.4553 - val_y1_output_root_mean_squared_error: 1.0197 - val_y2_output_root_mean_squared_error: 1.8165
# Epoch 96/500
# 614/614 [==============================] - 0s 122us/sample - loss: 2.9284 - y1_output_loss: 0.6935 - y2_output_loss: 2.2117 - y1_output_root_mean_squared_error: 0.8356 - y2_output_root_mean_squared_error: 1.4933 - val_loss: 2.7726 - val_y1_output_loss: 0.7993 - val_y2_output_loss: 1.9672 - val_y1_output_root_mean_squared_error: 0.9105 - val_y2_output_root_mean_squared_error: 1.3941
# Epoch 97/500
# 614/614 [==============================] - 0s 120us/sample - loss: 2.8569 - y1_output_loss: 0.6445 - y2_output_loss: 2.2035 - y1_output_root_mean_squared_error: 0.8021 - y2_output_root_mean_squared_error: 1.4878 - val_loss: 2.9480 - val_y1_output_loss: 0.7400 - val_y2_output_loss: 2.2322 - val_y1_output_root_mean_squared_error: 0.8762 - val_y2_output_root_mean_squared_error: 1.4766
# Epoch 98/500
# 614/614 [==============================] - 0s 121us/sample - loss: 3.8475 - y1_output_loss: 1.0488 - y2_output_loss: 2.7807 - y1_output_root_mean_squared_error: 1.0254 - y2_output_root_mean_squared_error: 1.6721 - val_loss: 3.7975 - val_y1_output_loss: 1.1398 - val_y2_output_loss: 2.6511 - val_y1_output_root_mean_squared_error: 1.0790 - val_y2_output_root_mean_squared_error: 1.6227
# Epoch 99/500
# 614/614 [==============================] - 0s 120us/sample - loss: 2.6282 - y1_output_loss: 0.6893 - y2_output_loss: 1.9481 - y1_output_root_mean_squared_error: 0.8255 - y2_output_root_mean_squared_error: 1.3953 - val_loss: 6.5774 - val_y1_output_loss: 2.4945 - val_y2_output_loss: 4.1949 - val_y1_output_root_mean_squared_error: 1.5725 - val_y2_output_root_mean_squared_error: 2.0260
# Epoch 100/500
# 614/614 [==============================] - 0s 120us/sample - loss: 4.3399 - y1_output_loss: 0.9789 - y2_output_loss: 3.3772 - y1_output_root_mean_squared_error: 0.9928 - y2_output_root_mean_squared_error: 1.8315 - val_loss: 5.3276 - val_y1_output_loss: 0.8698 - val_y2_output_loss: 4.4563 - val_y1_output_root_mean_squared_error: 0.9370 - val_y2_output_root_mean_squared_error: 2.1094
# Epoch 101/500
# 614/614 [==============================] - 0s 122us/sample - loss: 2.9221 - y1_output_loss: 0.6276 - y2_output_loss: 2.3159 - y1_output_root_mean_squared_error: 0.7883 - y2_output_root_mean_squared_error: 1.5168 - val_loss: 10.7150 - val_y1_output_loss: 3.0638 - val_y2_output_loss: 7.6282 - val_y1_output_root_mean_squared_error: 1.7694 - val_y2_output_root_mean_squared_error: 2.7539
# Epoch 102/500
# 614/614 [==============================] - 0s 118us/sample - loss: 3.0315 - y1_output_loss: 0.7020 - y2_output_loss: 2.3089 - y1_output_root_mean_squared_error: 0.8389 - y2_output_root_mean_squared_error: 1.5257 - val_loss: 2.9349 - val_y1_output_loss: 0.7205 - val_y2_output_loss: 2.2399 - val_y1_output_root_mean_squared_error: 0.8637 - val_y2_output_root_mean_squared_error: 1.4795
# Epoch 103/500
# 614/614 [==============================] - 0s 118us/sample - loss: 3.3375 - y1_output_loss: 0.8403 - y2_output_loss: 2.4722 - y1_output_root_mean_squared_error: 0.9184 - y2_output_root_mean_squared_error: 1.5793 - val_loss: 2.4180 - val_y1_output_loss: 0.6248 - val_y2_output_loss: 1.8349 - val_y1_output_root_mean_squared_error: 0.7981 - val_y2_output_root_mean_squared_error: 1.3345
# Epoch 104/500
# 614/614 [==============================] - 0s 118us/sample - loss: 2.7318 - y1_output_loss: 0.6358 - y2_output_loss: 2.0853 - y1_output_root_mean_squared_error: 0.7979 - y2_output_root_mean_squared_error: 1.4475 - val_loss: 2.7792 - val_y1_output_loss: 0.8066 - val_y2_output_loss: 1.9708 - val_y1_output_root_mean_squared_error: 0.8998 - val_y2_output_root_mean_squared_error: 1.4034
# Epoch 105/500
# 614/614 [==============================] - 0s 119us/sample - loss: 2.7428 - y1_output_loss: 0.5594 - y2_output_loss: 2.1961 - y1_output_root_mean_squared_error: 0.7412 - y2_output_root_mean_squared_error: 1.4810 - val_loss: 5.7108 - val_y1_output_loss: 1.4979 - val_y2_output_loss: 4.3372 - val_y1_output_root_mean_squared_error: 1.2245 - val_y2_output_root_mean_squared_error: 2.0522
# Epoch 106/500
# 614/614 [==============================] - 0s 120us/sample - loss: 2.7411 - y1_output_loss: 0.7450 - y2_output_loss: 2.0256 - y1_output_root_mean_squared_error: 0.8627 - y2_output_root_mean_squared_error: 1.4131 - val_loss: 3.7531 - val_y1_output_loss: 0.8209 - val_y2_output_loss: 2.9420 - val_y1_output_root_mean_squared_error: 0.9198 - val_y2_output_root_mean_squared_error: 1.7050
# Epoch 107/500
# 614/614 [==============================] - 0s 123us/sample - loss: 2.3389 - y1_output_loss: 0.5746 - y2_output_loss: 1.7952 - y1_output_root_mean_squared_error: 0.7540 - y2_output_root_mean_squared_error: 1.3306 - val_loss: 4.3914 - val_y1_output_loss: 1.3583 - val_y2_output_loss: 3.1149 - val_y1_output_root_mean_squared_error: 1.1636 - val_y2_output_root_mean_squared_error: 1.7428
# Epoch 108/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.3496 - y1_output_loss: 1.1101 - y2_output_loss: 3.2158 - y1_output_root_mean_squared_error: 1.0584 - y2_output_root_mean_squared_error: 1.7971 - val_loss: 3.8760 - val_y1_output_loss: 0.7520 - val_y2_output_loss: 3.0929 - val_y1_output_root_mean_squared_error: 0.8782 - val_y2_output_root_mean_squared_error: 1.7620
# Epoch 109/500
# 614/614 [==============================] - 0s 122us/sample - loss: 2.8668 - y1_output_loss: 0.6609 - y2_output_loss: 2.2130 - y1_output_root_mean_squared_error: 0.8119 - y2_output_root_mean_squared_error: 1.4858 - val_loss: 4.1974 - val_y1_output_loss: 1.1488 - val_y2_output_loss: 2.9862 - val_y1_output_root_mean_squared_error: 1.0852 - val_y2_output_root_mean_squared_error: 1.7377
# Epoch 110/500
# 614/614 [==============================] - 0s 122us/sample - loss: 2.3829 - y1_output_loss: 0.6631 - y2_output_loss: 1.7188 - y1_output_root_mean_squared_error: 0.8127 - y2_output_root_mean_squared_error: 1.3124 - val_loss: 2.8361 - val_y1_output_loss: 0.7070 - val_y2_output_loss: 2.1859 - val_y1_output_root_mean_squared_error: 0.8523 - val_y2_output_root_mean_squared_error: 1.4525
# Epoch 111/500
# 614/614 [==============================] - 0s 122us/sample - loss: 2.3895 - y1_output_loss: 0.6036 - y2_output_loss: 1.8048 - y1_output_root_mean_squared_error: 0.7741 - y2_output_root_mean_squared_error: 1.3380 - val_loss: 3.3562 - val_y1_output_loss: 1.3098 - val_y2_output_loss: 2.1116 - val_y1_output_root_mean_squared_error: 1.1235 - val_y2_output_root_mean_squared_error: 1.4470
# Epoch 112/500
# 614/614 [==============================] - 0s 120us/sample - loss: 2.2464 - y1_output_loss: 0.5222 - y2_output_loss: 1.7306 - y1_output_root_mean_squared_error: 0.7239 - y2_output_root_mean_squared_error: 1.3124 - val_loss: 2.3776 - val_y1_output_loss: 0.6996 - val_y2_output_loss: 1.6757 - val_y1_output_root_mean_squared_error: 0.8485 - val_y2_output_root_mean_squared_error: 1.2875
# Epoch 113/500
# 614/614 [==============================] - 0s 119us/sample - loss: 2.2577 - y1_output_loss: 0.4651 - y2_output_loss: 1.7847 - y1_output_root_mean_squared_error: 0.6843 - y2_output_root_mean_squared_error: 1.3377 - val_loss: 5.0837 - val_y1_output_loss: 1.4428 - val_y2_output_loss: 3.6684 - val_y1_output_root_mean_squared_error: 1.2013 - val_y2_output_root_mean_squared_error: 1.9081
# Epoch 114/500
# 614/614 [==============================] - 0s 121us/sample - loss: 2.7746 - y1_output_loss: 0.6502 - y2_output_loss: 2.1348 - y1_output_root_mean_squared_error: 0.8063 - y2_output_root_mean_squared_error: 1.4576 - val_loss: 5.9149 - val_y1_output_loss: 0.8662 - val_y2_output_loss: 5.1553 - val_y1_output_root_mean_squared_error: 0.9395 - val_y2_output_root_mean_squared_error: 2.2433
# Epoch 115/500
# 614/614 [==============================] - 0s 124us/sample - loss: 3.4721 - y1_output_loss: 0.7533 - y2_output_loss: 2.6924 - y1_output_root_mean_squared_error: 0.8698 - y2_output_root_mean_squared_error: 1.6479 - val_loss: 2.2150 - val_y1_output_loss: 0.5015 - val_y2_output_loss: 1.7402 - val_y1_output_root_mean_squared_error: 0.7200 - val_y2_output_root_mean_squared_error: 1.3025
# Epoch 116/500
# 614/614 [==============================] - 0s 120us/sample - loss: 2.3088 - y1_output_loss: 0.5815 - y2_output_loss: 1.7258 - y1_output_root_mean_squared_error: 0.7578 - y2_output_root_mean_squared_error: 1.3170 - val_loss: 4.7223 - val_y1_output_loss: 1.5205 - val_y2_output_loss: 3.2628 - val_y1_output_root_mean_squared_error: 1.2422 - val_y2_output_root_mean_squared_error: 1.7831
# Epoch 117/500
# 614/614 [==============================] - 0s 120us/sample - loss: 2.6310 - y1_output_loss: 0.6139 - y2_output_loss: 2.0390 - y1_output_root_mean_squared_error: 0.7836 - y2_output_root_mean_squared_error: 1.4202 - val_loss: 5.1301 - val_y1_output_loss: 1.1020 - val_y2_output_loss: 4.0318 - val_y1_output_root_mean_squared_error: 1.0587 - val_y2_output_root_mean_squared_error: 2.0023
# Epoch 118/500
# 614/614 [==============================] - 0s 120us/sample - loss: 2.4829 - y1_output_loss: 0.5564 - y2_output_loss: 1.9063 - y1_output_root_mean_squared_error: 0.7484 - y2_output_root_mean_squared_error: 1.3866 - val_loss: 2.1614 - val_y1_output_loss: 0.5020 - val_y2_output_loss: 1.7222 - val_y1_output_root_mean_squared_error: 0.7173 - val_y2_output_root_mean_squared_error: 1.2833
# Epoch 119/500
# 614/614 [==============================] - 0s 121us/sample - loss: 2.5160 - y1_output_loss: 0.5548 - y2_output_loss: 1.9933 - y1_output_root_mean_squared_error: 0.7415 - y2_output_root_mean_squared_error: 1.4022 - val_loss: 7.1476 - val_y1_output_loss: 1.3033 - val_y2_output_loss: 5.8321 - val_y1_output_root_mean_squared_error: 1.1589 - val_y2_output_root_mean_squared_error: 2.4092
# Epoch 120/500
# 614/614 [==============================] - 0s 121us/sample - loss: 2.7833 - y1_output_loss: 0.6516 - y2_output_loss: 2.1157 - y1_output_root_mean_squared_error: 0.8088 - y2_output_root_mean_squared_error: 1.4592 - val_loss: 2.1562 - val_y1_output_loss: 0.5034 - val_y2_output_loss: 1.6680 - val_y1_output_root_mean_squared_error: 0.7206 - val_y2_output_root_mean_squared_error: 1.2794
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 121us/sample - loss: 0.3920 - y1_output_loss: 0.1197 - y2_output_loss: 0.2696 - y1_output_root_mean_squared_error: 0.3464 - y2_output_root_mean_squared_error: 0.5215 - val_loss: 0.6793 - val_y1_output_loss: 0.1638 - val_y2_output_loss: 0.5084 - val_y1_output_root_mean_squared_error: 0.4069 - val_y2_output_root_mean_squared_error: 0.7167
# Epoch 462/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4356 - y1_output_loss: 0.1356 - y2_output_loss: 0.2983 - y1_output_root_mean_squared_error: 0.3693 - y2_output_root_mean_squared_error: 0.5470 - val_loss: 0.7433 - val_y1_output_loss: 0.1669 - val_y2_output_loss: 0.5915 - val_y1_output_root_mean_squared_error: 0.4093 - val_y2_output_root_mean_squared_error: 0.7588
# Epoch 463/500
# 614/614 [==============================] - 0s 121us/sample - loss: 0.3598 - y1_output_loss: 0.1169 - y2_output_loss: 0.2406 - y1_output_root_mean_squared_error: 0.3434 - y2_output_root_mean_squared_error: 0.4918 - val_loss: 0.7595 - val_y1_output_loss: 0.1534 - val_y2_output_loss: 0.6034 - val_y1_output_root_mean_squared_error: 0.3935 - val_y2_output_root_mean_squared_error: 0.7776
# Epoch 464/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3956 - y1_output_loss: 0.1161 - y2_output_loss: 0.2840 - y1_output_root_mean_squared_error: 0.3386 - y2_output_root_mean_squared_error: 0.5300 - val_loss: 0.8469 - val_y1_output_loss: 0.1700 - val_y2_output_loss: 0.6748 - val_y1_output_root_mean_squared_error: 0.4169 - val_y2_output_root_mean_squared_error: 0.8204
# Epoch 465/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.5135 - y1_output_loss: 0.1557 - y2_output_loss: 0.3620 - y1_output_root_mean_squared_error: 0.3918 - y2_output_root_mean_squared_error: 0.6000 - val_loss: 1.6134 - val_y1_output_loss: 0.3820 - val_y2_output_loss: 1.2253 - val_y1_output_root_mean_squared_error: 0.6217 - val_y2_output_root_mean_squared_error: 1.1076
# Epoch 466/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3947 - y1_output_loss: 0.1227 - y2_output_loss: 0.2736 - y1_output_root_mean_squared_error: 0.3492 - y2_output_root_mean_squared_error: 0.5223 - val_loss: 1.8218 - val_y1_output_loss: 0.5135 - val_y2_output_loss: 1.3266 - val_y1_output_root_mean_squared_error: 0.7066 - val_y2_output_root_mean_squared_error: 1.1500
# Epoch 467/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.5088 - y1_output_loss: 0.1394 - y2_output_loss: 0.3663 - y1_output_root_mean_squared_error: 0.3744 - y2_output_root_mean_squared_error: 0.6072 - val_loss: 0.8409 - val_y1_output_loss: 0.2587 - val_y2_output_loss: 0.5715 - val_y1_output_root_mean_squared_error: 0.5098 - val_y2_output_root_mean_squared_error: 0.7623
# Epoch 468/500
# 614/614 [==============================] - 0s 121us/sample - loss: 0.3716 - y1_output_loss: 0.1331 - y2_output_loss: 0.2376 - y1_output_root_mean_squared_error: 0.3639 - y2_output_root_mean_squared_error: 0.4890 - val_loss: 0.7938 - val_y1_output_loss: 0.2141 - val_y2_output_loss: 0.5713 - val_y1_output_root_mean_squared_error: 0.4674 - val_y2_output_root_mean_squared_error: 0.7585
# Epoch 469/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.5483 - y1_output_loss: 0.1352 - y2_output_loss: 0.4094 - y1_output_root_mean_squared_error: 0.3690 - y2_output_root_mean_squared_error: 0.6420 - val_loss: 0.6989 - val_y1_output_loss: 0.1445 - val_y2_output_loss: 0.5460 - val_y1_output_root_mean_squared_error: 0.3849 - val_y2_output_root_mean_squared_error: 0.7421
# Epoch 470/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4106 - y1_output_loss: 0.1336 - y2_output_loss: 0.2751 - y1_output_root_mean_squared_error: 0.3663 - y2_output_root_mean_squared_error: 0.5258 - val_loss: 0.7820 - val_y1_output_loss: 0.1811 - val_y2_output_loss: 0.5957 - val_y1_output_root_mean_squared_error: 0.4287 - val_y2_output_root_mean_squared_error: 0.7735
# Epoch 471/500
# 614/614 [==============================] - 0s 120us/sample - loss: 0.4431 - y1_output_loss: 0.1479 - y2_output_loss: 0.2962 - y1_output_root_mean_squared_error: 0.3852 - y2_output_root_mean_squared_error: 0.5429 - val_loss: 1.3594 - val_y1_output_loss: 0.2645 - val_y2_output_loss: 1.0710 - val_y1_output_root_mean_squared_error: 0.5220 - val_y2_output_root_mean_squared_error: 1.0426
# Epoch 472/500
# 614/614 [==============================] - 0s 120us/sample - loss: 0.3438 - y1_output_loss: 0.1186 - y2_output_loss: 0.2256 - y1_output_root_mean_squared_error: 0.3428 - y2_output_root_mean_squared_error: 0.4756 - val_loss: 0.9873 - val_y1_output_loss: 0.3134 - val_y2_output_loss: 0.6826 - val_y1_output_root_mean_squared_error: 0.5532 - val_y2_output_root_mean_squared_error: 0.8254
# Epoch 473/500
# 614/614 [==============================] - 0s 121us/sample - loss: 0.5317 - y1_output_loss: 0.1767 - y2_output_loss: 0.3553 - y1_output_root_mean_squared_error: 0.4185 - y2_output_root_mean_squared_error: 0.5971 - val_loss: 2.1859 - val_y1_output_loss: 0.7100 - val_y2_output_loss: 1.4603 - val_y1_output_root_mean_squared_error: 0.8531 - val_y2_output_root_mean_squared_error: 1.2075
# Epoch 474/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.6017 - y1_output_loss: 0.1857 - y2_output_loss: 0.4114 - y1_output_root_mean_squared_error: 0.4326 - y2_output_root_mean_squared_error: 0.6439 - val_loss: 0.6970 - val_y1_output_loss: 0.1577 - val_y2_output_loss: 0.5268 - val_y1_output_root_mean_squared_error: 0.4016 - val_y2_output_root_mean_squared_error: 0.7320
# Epoch 475/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4795 - y1_output_loss: 0.1223 - y2_output_loss: 0.3532 - y1_output_root_mean_squared_error: 0.3507 - y2_output_root_mean_squared_error: 0.5970 - val_loss: 0.7727 - val_y1_output_loss: 0.1855 - val_y2_output_loss: 0.5979 - val_y1_output_root_mean_squared_error: 0.4363 - val_y2_output_root_mean_squared_error: 0.7631
# Epoch 476/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4151 - y1_output_loss: 0.1321 - y2_output_loss: 0.2810 - y1_output_root_mean_squared_error: 0.3648 - y2_output_root_mean_squared_error: 0.5311 - val_loss: 0.7421 - val_y1_output_loss: 0.1364 - val_y2_output_loss: 0.6105 - val_y1_output_root_mean_squared_error: 0.3723 - val_y2_output_root_mean_squared_error: 0.7768
# Epoch 477/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3272 - y1_output_loss: 0.1186 - y2_output_loss: 0.2156 - y1_output_root_mean_squared_error: 0.3414 - y2_output_root_mean_squared_error: 0.4589 - val_loss: 3.1985 - val_y1_output_loss: 0.7403 - val_y2_output_loss: 2.4654 - val_y1_output_root_mean_squared_error: 0.8597 - val_y2_output_root_mean_squared_error: 1.5683
# Epoch 478/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.4301 - y1_output_loss: 0.1352 - y2_output_loss: 0.2928 - y1_output_root_mean_squared_error: 0.3687 - y2_output_root_mean_squared_error: 0.5424 - val_loss: 0.7049 - val_y1_output_loss: 0.1466 - val_y2_output_loss: 0.5478 - val_y1_output_root_mean_squared_error: 0.3859 - val_y2_output_root_mean_squared_error: 0.7456
# Epoch 479/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.4077 - y1_output_loss: 0.1232 - y2_output_loss: 0.2933 - y1_output_root_mean_squared_error: 0.3507 - y2_output_root_mean_squared_error: 0.5336 - val_loss: 1.8643 - val_y1_output_loss: 0.3957 - val_y2_output_loss: 1.4211 - val_y1_output_root_mean_squared_error: 0.6382 - val_y2_output_root_mean_squared_error: 1.2071
# Epoch 480/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.4748 - y1_output_loss: 0.1419 - y2_output_loss: 0.3451 - y1_output_root_mean_squared_error: 0.3750 - y2_output_root_mean_squared_error: 0.5780 - val_loss: 4.7561 - val_y1_output_loss: 0.7176 - val_y2_output_loss: 4.0987 - val_y1_output_root_mean_squared_error: 0.8390 - val_y2_output_root_mean_squared_error: 2.0130
# Epoch 481/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.6036 - y1_output_loss: 0.1830 - y2_output_loss: 0.4246 - y1_output_root_mean_squared_error: 0.4278 - y2_output_root_mean_squared_error: 0.6486 - val_loss: 1.6428 - val_y1_output_loss: 0.2883 - val_y2_output_loss: 1.3748 - val_y1_output_root_mean_squared_error: 0.5338 - val_y2_output_root_mean_squared_error: 1.1652
# Epoch 482/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3881 - y1_output_loss: 0.1207 - y2_output_loss: 0.2683 - y1_output_root_mean_squared_error: 0.3480 - y2_output_root_mean_squared_error: 0.5168 - val_loss: 0.9471 - val_y1_output_loss: 0.1470 - val_y2_output_loss: 0.7998 - val_y1_output_root_mean_squared_error: 0.3863 - val_y2_output_root_mean_squared_error: 0.8932
# Epoch 483/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.5594 - y1_output_loss: 0.1511 - y2_output_loss: 0.4087 - y1_output_root_mean_squared_error: 0.3885 - y2_output_root_mean_squared_error: 0.6391 - val_loss: 0.7358 - val_y1_output_loss: 0.2026 - val_y2_output_loss: 0.5393 - val_y1_output_root_mean_squared_error: 0.4521 - val_y2_output_root_mean_squared_error: 0.7290
# Epoch 484/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3527 - y1_output_loss: 0.1179 - y2_output_loss: 0.2326 - y1_output_root_mean_squared_error: 0.3442 - y2_output_root_mean_squared_error: 0.4840 - val_loss: 0.7421 - val_y1_output_loss: 0.1529 - val_y2_output_loss: 0.5944 - val_y1_output_root_mean_squared_error: 0.3925 - val_y2_output_root_mean_squared_error: 0.7668
# Epoch 485/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4323 - y1_output_loss: 0.1306 - y2_output_loss: 0.3004 - y1_output_root_mean_squared_error: 0.3609 - y2_output_root_mean_squared_error: 0.5495 - val_loss: 0.7604 - val_y1_output_loss: 0.1621 - val_y2_output_loss: 0.5879 - val_y1_output_root_mean_squared_error: 0.4080 - val_y2_output_root_mean_squared_error: 0.7706
# Epoch 486/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4126 - y1_output_loss: 0.1240 - y2_output_loss: 0.2855 - y1_output_root_mean_squared_error: 0.3533 - y2_output_root_mean_squared_error: 0.5365 - val_loss: 0.6861 - val_y1_output_loss: 0.1815 - val_y2_output_loss: 0.4967 - val_y1_output_root_mean_squared_error: 0.4263 - val_y2_output_root_mean_squared_error: 0.7102
# Epoch 487/500
# 614/614 [==============================] - 0s 120us/sample - loss: 0.4241 - y1_output_loss: 0.1480 - y2_output_loss: 0.2749 - y1_output_root_mean_squared_error: 0.3850 - y2_output_root_mean_squared_error: 0.5252 - val_loss: 0.7437 - val_y1_output_loss: 0.1793 - val_y2_output_loss: 0.5450 - val_y1_output_root_mean_squared_error: 0.4285 - val_y2_output_root_mean_squared_error: 0.7484
# Epoch 488/500
# 614/614 [==============================] - 0s 119us/sample - loss: 0.4105 - y1_output_loss: 0.1444 - y2_output_loss: 0.2651 - y1_output_root_mean_squared_error: 0.3799 - y2_output_root_mean_squared_error: 0.5159 - val_loss: 0.7960 - val_y1_output_loss: 0.2218 - val_y2_output_loss: 0.5707 - val_y1_output_root_mean_squared_error: 0.4734 - val_y2_output_root_mean_squared_error: 0.7562
# Epoch 489/500
# 614/614 [==============================] - 0s 118us/sample - loss: 0.5472 - y1_output_loss: 0.1676 - y2_output_loss: 0.3790 - y1_output_root_mean_squared_error: 0.4093 - y2_output_root_mean_squared_error: 0.6162 - val_loss: 1.1531 - val_y1_output_loss: 0.2632 - val_y2_output_loss: 0.8886 - val_y1_output_root_mean_squared_error: 0.5184 - val_y2_output_root_mean_squared_error: 0.9404
# Epoch 490/500
# 614/614 [==============================] - 0s 119us/sample - loss: 0.5165 - y1_output_loss: 0.1550 - y2_output_loss: 0.3592 - y1_output_root_mean_squared_error: 0.3955 - y2_output_root_mean_squared_error: 0.6001 - val_loss: 0.8687 - val_y1_output_loss: 0.1513 - val_y2_output_loss: 0.7228 - val_y1_output_root_mean_squared_error: 0.3926 - val_y2_output_root_mean_squared_error: 0.8453
# Epoch 491/500
# 614/614 [==============================] - 0s 118us/sample - loss: 0.3677 - y1_output_loss: 0.1330 - y2_output_loss: 0.2317 - y1_output_root_mean_squared_error: 0.3663 - y2_output_root_mean_squared_error: 0.4833 - val_loss: 0.7374 - val_y1_output_loss: 0.2044 - val_y2_output_loss: 0.5196 - val_y1_output_root_mean_squared_error: 0.4582 - val_y2_output_root_mean_squared_error: 0.7263
# Epoch 492/500
# 614/614 [==============================] - 0s 118us/sample - loss: 0.2938 - y1_output_loss: 0.1065 - y2_output_loss: 0.1886 - y1_output_root_mean_squared_error: 0.3254 - y2_output_root_mean_squared_error: 0.4335 - val_loss: 1.0722 - val_y1_output_loss: 0.1667 - val_y2_output_loss: 0.9209 - val_y1_output_root_mean_squared_error: 0.4114 - val_y2_output_root_mean_squared_error: 0.9502
# Epoch 493/500
# 614/614 [==============================] - 0s 119us/sample - loss: 0.3753 - y1_output_loss: 0.1243 - y2_output_loss: 0.2482 - y1_output_root_mean_squared_error: 0.3541 - y2_output_root_mean_squared_error: 0.4998 - val_loss: 0.6318 - val_y1_output_loss: 0.1444 - val_y2_output_loss: 0.4837 - val_y1_output_root_mean_squared_error: 0.3821 - val_y2_output_root_mean_squared_error: 0.6970
# Epoch 494/500
# 614/614 [==============================] - 0s 120us/sample - loss: 0.4708 - y1_output_loss: 0.1557 - y2_output_loss: 0.3125 - y1_output_root_mean_squared_error: 0.3958 - y2_output_root_mean_squared_error: 0.5605 - val_loss: 0.7991 - val_y1_output_loss: 0.2104 - val_y2_output_loss: 0.5805 - val_y1_output_root_mean_squared_error: 0.4610 - val_y2_output_root_mean_squared_error: 0.7658
# Epoch 495/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.4202 - y1_output_loss: 0.1329 - y2_output_loss: 0.2839 - y1_output_root_mean_squared_error: 0.3660 - y2_output_root_mean_squared_error: 0.5350 - val_loss: 0.8476 - val_y1_output_loss: 0.1868 - val_y2_output_loss: 0.6573 - val_y1_output_root_mean_squared_error: 0.4345 - val_y2_output_root_mean_squared_error: 0.8117
# Epoch 496/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.3943 - y1_output_loss: 0.1212 - y2_output_loss: 0.2713 - y1_output_root_mean_squared_error: 0.3477 - y2_output_root_mean_squared_error: 0.5229 - val_loss: 0.7343 - val_y1_output_loss: 0.1665 - val_y2_output_loss: 0.5664 - val_y1_output_root_mean_squared_error: 0.4125 - val_y2_output_root_mean_squared_error: 0.7510
# Epoch 497/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.4319 - y1_output_loss: 0.1352 - y2_output_loss: 0.2939 - y1_output_root_mean_squared_error: 0.3687 - y2_output_root_mean_squared_error: 0.5440 - val_loss: 0.7064 - val_y1_output_loss: 0.1822 - val_y2_output_loss: 0.5184 - val_y1_output_root_mean_squared_error: 0.4323 - val_y2_output_root_mean_squared_error: 0.7207
# Epoch 498/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.4007 - y1_output_loss: 0.1362 - y2_output_loss: 0.2628 - y1_output_root_mean_squared_error: 0.3702 - y2_output_root_mean_squared_error: 0.5135 - val_loss: 0.7552 - val_y1_output_loss: 0.1545 - val_y2_output_loss: 0.5856 - val_y1_output_root_mean_squared_error: 0.3957 - val_y2_output_root_mean_squared_error: 0.7737
# Epoch 499/500
# 614/614 [==============================] - 0s 120us/sample - loss: 0.4370 - y1_output_loss: 0.1512 - y2_output_loss: 0.2843 - y1_output_root_mean_squared_error: 0.3900 - y2_output_root_mean_squared_error: 0.5338 - val_loss: 0.7211 - val_y1_output_loss: 0.1405 - val_y2_output_loss: 0.5838 - val_y1_output_root_mean_squared_error: 0.3795 - val_y2_output_root_mean_squared_error: 0.7597
# Epoch 500/500
# 614/614 [==============================] - 0s 118us/sample - loss: 0.3109 - y1_output_loss: 0.1176 - y2_output_loss: 0.1934 - y1_output_root_mean_squared_error: 0.3410 - y2_output_root_mean_squared_error: 0.4412 - val_loss: 1.1637 - val_y1_output_loss: 0.4193 - val_y2_output_loss: 0.7249 - val_y1_output_root_mean_squared_error: 0.6547 - val_y2_output_root_mean_squared_error: 0.8574

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
